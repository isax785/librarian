# %% [markdown]
# ```python
#     def git(git_args)
#         cmd = f"git -C {self.storagepath} {git_args}"
#
#     def diff():
#         r = self.git(f"diff --name-status {since_rev} HEAD")
# ```
#
# *Relative paths* are obtained from any git command.
#
# Retrieve tree example
# ```shell
#     >> git ls-tree -r master
#     100644 blob 7f83d0aed475db7505532f9b079d2d6fa0cbae33    .gitignore
#     100644 blob 7b0511d77ac11c48085ef98ccd20f19fb3d8389b    client/download.py
#     100644 blob ccea248231af94f0e13a596e69dd60c47df70cdf    client/obj/db.py
#     100644 blob 0de9a7e5656ee8f016a132cf3c68f72f831b087a    client/pull.py
#     100644 blob 398692d8e3373bb3aa6f359c09d5f373842d0cee    client/requirements.txt
# ```
#
# **name only**:
#
# ```shell
#     >> git ls-tree -r --name-only  master
#     .gitignore
#     client/download.py
#     client/obj/db.py
#     client/pull.py
#     client/requirements.txt
# ```
#
# Git `diff` example:
#
# ```shell
# >> git diff --name-status 3dff0d8063  HEAD
#     M       .gitignore
#     R073    client/main.py  client/download.py
#     A       client/pull.py
#     A       readme.md
#     M       server/app.py
#     M       server/obj/db.py
#     A       src/drawings.excalidraw
#     A       src/img_md/2024-04-15-12-22-18.png
# ```

# %%
# %load_ext autoreload
# %autoreload 2
from librarian import Librarian
# Out:
# {'repo-abs-path': 'C:\\Users\\i.stiaccini\\Desktop\\launcher-downloader'}
